# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("NYC_Jobs.csv")
print df.shape
print df.dtypes
df.head(5)
# Out:
# (4261, 26)
# Job ID                         int64
# Agency                        object
# Posting Type                  object
# # Of Positions                 int64
# Business Title                object
# Civil Service Title           object
# Title Code No                 object
# Level                         object
# Salary Range From              int64
# Salary Range To                int64
# Salary Frequency              object
# Work Location                 object
# Division/Work Unit            object
# Job Description               object
# Minimum Qual Requirements     object
# Preferred Skills              object
# Additional Information        object
# To Apply                      object
# Hours/Shift                   object
# Work Location 1               object
# Recruitment Contact          float64
# Residency Requirement         object
# Posting Date                  object
# Post Until                    object
# Posting Updated               object
# ...

# %%
df.columns
# Out:
# Index([u'Job ID', u'Agency', u'Posting Type', u'# Of Positions',
#        u'Business Title', u'Civil Service Title', u'Title Code No', u'Level',
#        u'Salary Range From', u'Salary Range To', u'Salary Frequency',
#        u'Work Location', u'Division/Work Unit', u'Job Description',
#        u'Minimum Qual Requirements', u'Preferred Skills',
#        u'Additional Information', u'To Apply', u'Hours/Shift',
#        u'Work Location 1', u'Recruitment Contact', u'Residency Requirement',
#        u'Posting Date', u'Post Until', u'Posting Updated', u'Process Date'],
#       dtype='object')

# %%
data_by_agency = df.groupby("Agency")
grouped_data = data_by_agency.sum()
grouped_data.sort("# Of Positions", ascending = False)
# Out:
#                                    Job ID  # Of Positions  Salary Range From  \
# Agency
# DEPT OF HEALTH/MENTAL HYGIENE   305474072            3397           64175783
# DEPT OF PARKS & RECREATION       25481737            2034            6691010
# POLICE DEPARTMENT                18250530             768            3677677
# ADMIN FOR CHILDREN'S SVCS        49636595             637           13253521
# DEPT OF ENVIRONMENT PROTECTION   92178568             606           23552038
# DEPT OF DESIGN & CONSTRUCTION    39700327             529            9389078
# DEPARTMENT OF BUILDINGS          14867240             450            3587164
# DEPARTMENT OF TRANSPORTATION     40299527             423            9707018
# NYC HOUSING AUTHORITY            11668664             373            4329587
# DEPT OF INFO TECH & TELECOMM     58864976             349           16494956
# LAW DEPARTMENT                   14164998             281            3000933
# ...

# %%
df.sort("Salary Range From").head(20)
# Out:
#       Job ID                          Agency Posting Type  # Of Positions  \
# 2032  239959    DEPARTMENT OF BUSINESS SERV.     Internal               1
# 1347  235267           DEPARTMENT OF FINANCE     Internal               1
# 1343  235266           DEPARTMENT OF FINANCE     Internal               1
# 1342  235265           DEPARTMENT OF FINANCE     Internal               1
# 1341  235265           DEPARTMENT OF FINANCE     External               1
# 1340  235264           DEPARTMENT OF FINANCE     Internal               2
# 1339  235266           DEPARTMENT OF FINANCE     External               1
# 1326  235264           DEPARTMENT OF FINANCE     External               2
# 1325  235263           DEPARTMENT OF FINANCE     Internal               3
# 1348  235267           DEPARTMENT OF FINANCE     External               1
# 1323  235263           DEPARTMENT OF FINANCE     External               3
# 1321  235262           DEPARTMENT OF FINANCE     Internal               1
# ...

# %%
df.sort("Salary Range To", ascending = False).head(10)
# Out:
#       Job ID                         Agency Posting Type  # Of Positions  \
# 977   228766  DEPT OF HEALTH/MENTAL HYGIENE     Internal               7
# 976   228766  DEPT OF HEALTH/MENTAL HYGIENE     External               7
# 809   228116   DEPARTMENT OF BUSINESS SERV.     External               1
# 2007  239931  DEPT OF DESIGN & CONSTRUCTION     Internal               1
# 2008  239931  DEPT OF DESIGN & CONSTRUCTION     External               1
# 2012  239934  DEPT OF DESIGN & CONSTRUCTION     Internal               1
# 2014  239932  DEPT OF DESIGN & CONSTRUCTION     External               1
# 2015  239932  DEPT OF DESIGN & CONSTRUCTION     Internal               1
# 2016  239934  DEPT OF DESIGN & CONSTRUCTION     External               1
# 810   228116   DEPARTMENT OF BUSINESS SERV.     Internal               1
#
#                                          Business Title  \
# 977   Physician, Bureau of Sexually Transmitted Dise...
# ...
